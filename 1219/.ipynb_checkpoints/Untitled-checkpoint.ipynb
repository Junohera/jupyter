# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import matplotlib.pylab as plt

import tensorflow as tf

# %%
# !pip install -q -U tf-hub
# Out:
#   ERROR: Could not find a version that satisfies the requirement tf-hub (from versions: none)
# ERROR: No matching distribution found for tf-hub

# %%
import tensorflow_hub as hub

from tensorflow.keras import layers

from tensorflow.keras.models import Sequential

# %%
model = Sequential([
    hub.keras_layer("https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/2", input_shape(224,224,3))
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-be0da520b2bc> in <module>
#       1 model = Sequential([
# ----> 2     hub.keras_layer("https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/2", input_shape(224,224,3))
#       3 ])
#
# NameError: name 'input_shape' is not defined

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-5f15418b3570> in <module>
# ----> 1 model.summary()
#
# NameError: name 'model' is not defined

# %%
dir(model.layer[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-51f01e9286b8> in <module>
# ----> 1 dir(model.layer[0])
#
# NameError: name 'model' is not defined

# %%
classifier_url ="https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/2" #@param {type:"string"}

# %%
IMAGE_SHAPE = (224, 224)

classifier = tf.keras.Sequential([
    hub.KerasLayer(classifier_url, input_shape=IMAGE_SHAPE+(3,))
])

# %%
import numpy as np
import PIL.Image as Image

grace_hopper = tf.keras.utils.get_file('%ED%94%BC%EC%B9%B4%EC%B8%84.jpg','https://post-phinf.pstatic.net/MjAxNzEyMTNfMjIx/MDAxNTEzMTI1MDYwNTUw.Q6LO7KVPRttYT6Y8eSCkMUSjxvXW9IWMSVCQmWVwOwAg.g6zfoPUlOJfSXTcja4bKgesJyYakdIEehHTAW1rrnogg.JPEG/%ED%94%BC%EC%B9%B4%EC%B8%84.jpg?type=w1200')
grace_hopper = Image.open(grace_hopper).resize(IMAGE_SHAPE)
grace_hopper
# Out:
# Downloading data from https://post-phinf.pstatic.net/MjAxNzEyMTNfMjIx/MDAxNTEzMTI1MDYwNTUw.Q6LO7KVPRttYT6Y8eSCkMUSjxvXW9IWMSVCQmWVwOwAg.g6zfoPUlOJfSXTcja4bKgesJyYakdIEehHTAW1rrnogg.JPEG/%ED%94%BC%EC%B9%B4%EC%B8%84.jpg?type=w1200
# 57344/52429 [================================] - 0s 0us/step
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F866D304B10>
