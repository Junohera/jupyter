# %%
from sklearn.ensemble import VotingClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.linear_model import LogisticRegression

# %%
vote = VotingClassifier([('knn',KNeighborsClassifier()), ('lr',LogisticRegression())])
vote.fit(data.data, data.target)
# Out:
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# VotingClassifier(estimators=[('knn',
#                               KNeighborsClassifier(algorithm='auto',
#                                                    leaf_size=30,
#                                                    metric='minkowski',
#                                                    metric_params=None,
#                                                    n_jobs=None, n_neighbors=5,
#                                                    p=2, weights='uniform')),
#                              ('lr',
# ...

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.datasets import load_iris

# %%
data = load_iris()

# %%
cross_val_score(vote, data.data, data.target, cv = 10)
# Out:
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# ...

# %%
cross_val_score(KNeighborsClassifier(), data.data, data.target, cv = 10)
# Out:
# array([1.        , 0.93333333, 1.        , 1.        , 0.86666667,
#        0.93333333, 0.93333333, 1.        , 1.        , 1.        ])

# %%
cross_val_score(LogisticRegression(), data.data, data.target, cv = 10)
# Out:
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# ...

# %%
from sklearn.ensemble import BaggingClassifier # 복원추출하여 그만큼

# %%
bag = BaggingClassifier(LogisticRegression(), 5)

# %%
t = cross_val_score(bag, data.data, data.target, cv = 5)
# Out:
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# ...

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada = AdaBoostClassifier(LogisticRegression())

# %%
cross_val_score(ada, data.data, data.target, cv = 10)
# Out:
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# ...

# %%
from sklearn.ensemble import gradient_boosting

# %%
from mlxtend.classifier import StackingClassifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
stack = StackingClassifier([KNeighborsClassifier(), GaussianNB()], LogisticRegression())

# %%
cross_val_score(stack, data.data, data.target, cv=10)
# Out:
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# ...

# %%
# wine데이터 ensemble써서 가장 좋은 모델찾기

# %%
from sklearn.datasets import load_wine
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.dummy import DummyClassifier

skf = StratifiedKFold(10)

# %%
data = load_wine()
a = pd.DataFrame(data.data, columns=data.feature_names)
b = pd.DataFrame(data.target, columns=['target'])
wine = pd.concat([a, b], axis=1)

bag = BaggingClassifier(LogisticRegression())

pipe = make_pipeline(StandardScaler(), DummyClassifier())
pipe.fit(wine.iloc[:,:-1], wine.target)
pipe = Pipeline([('std', StandardScaler()), ('clf', BaggingClassifier(KNeighborsClassifier()))])

# %%
pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('std', StandardScaler(copy=True, with_mean=True, with_std=True)),
#   ('clf',
#    BaggingClassifier(base_estimator=KNeighborsClassifier(algorithm='auto',
#                                                          leaf_size=30,
#                                                          metric='minkowski',
#                                                          metric_params=None,
#                                                          n_jobs=None,
#                                                          n_neighbors=5, p=2,
#                                                          weights='uniform'),
#                      bootstrap=True, bootstrap_features=False, max_features=1.0,
#                      max_samples=1.0, n_estimators=10, n_jobs=None,
#                      oob_score=False, random_state=None, verbose=0,
#                      warm_start=False))],
#  'verbose': False,
# ...

# %%
param_grid = [
    {'clf': [LogisticRegression()], 'clf__C' : [1.,2.,3.]},
    {'clf': [BaggingClassifier(KNeighborsClassifier())], 'clf__base_estimator__n_neighbors' : [1,2,3,4,5,6]},
    {'clf': [BaggingClassifier(KNeighborsClassifier())], 'clf__base_estimator__p' : [1,2,3,4,5,6]}
]

# %%
pipe
# Out:
# Pipeline(memory=None,
#          steps=[('std',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('clf',
#                  BaggingClassifier(base_estimator=KNeighborsClassifier(algorithm='auto',
#                                                                        leaf_size=30,
#                                                                        metric='minkowski',
#                                                                        metric_params=None,
#                                                                        n_jobs=None,
#                                                                        n_neighbors=5,
#                                                                        p=2,
#                                                                        weights='uniform'),
#                                    bootstrap=True, bootstrap_features=False,
# ...

# %%
grid = GridSearchCV(pipe, param_grid, cv=skf)

# %%
grid.fit(wine.iloc[:,:-1], wine.iloc[:,-1])
# Out:
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# ...

# %%
grid.best_params_
# Out:
# {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                     intercept_scaling=1, l1_ratio=None, max_iter=100,
#                     multi_class='warn', n_jobs=None, penalty='l2',
#                     random_state=None, solver='warn', tol=0.0001, verbose=0,
#                     warm_start=False), 'clf__C': 1.0}

# %%
vote = VotingClassifier([('knn', KNeighborsClassifier()), ('lr', LogisticRegression())])
vote.fit(wine.iloc[:,:-1], wine.target)
# Out:
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# VotingClassifier(estimators=[('knn',
#                               KNeighborsClassifier(algorithm='auto',
#                                                    leaf_size=30,
#                                                    metric='minkowski',
#                                                    metric_params=None,
#                                                    n_jobs=None, n_neighbors=5,
#                                                    p=2, weights='uniform')),
#                              ('lr',
# ...

# %%
stack = StackingClassifier([pipe, vote], LogisticRegression())

# %%
ada = AdaBoostClassifier(stack)

# %%
cross_val_score(ada, wine.iloc[:,:-1], wine.target, cv=skf).mean()
# Out:
# /home/ai39/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:530: FutureWarning: From version 0.22, errors during fit will result in a cross validation score of NaN by default. Use error_score='raise' if you want an exception raised or error_score=np.nan to adopt the behavior from version 0.22.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-430-513ab8e56ba9> in <module>
# ----> 1 cross_val_score(ada, wine.iloc[:,:-1], wine.target, cv=skf).mean()
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     389                                 fit_params=fit_params,
#     390                                 pre_dispatch=pre_dispatch,
# ...

# %%
du = DummyClassifier()
