# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('../../다운로드/accident.csv', encoding='cp949')

# %%
data
# Out:
#       월    주야      주      야
# 0    1월  사고건수   8035   7981
# 1   NaN  사망자수    190    199
# 2   NaN  부상자수  12589  12505
# 3    2월  사고건수   7241   6946
# 4   NaN  사망자수    136    199
# 5   NaN  부상자수  11440  10815
# 6    3월  사고건수   9036   8429
# 7   NaN  사망자수    198    211
# 8   NaN  부상자수  13599  12862
# 9    4월  사고건수   9620   8411
# 10  NaN  사망자수    164    216
# 11  NaN  부상자수  14722  13073
# 12   5월  사고건수  10593   9093
# 13  NaN  사망자수    215    205
# 14  NaN  부상자수  15843  13833
# 15   6월  사고건수   9960   8369
# 16  NaN  사망자수    195    241
# 17  NaN  부상자수  15161  12512
# 18   7월  사고건수  10010   8431
# 19  NaN  사망자수    221    223
# 20  NaN  부상자수  15531  12856
# 21   8월  사고건수  10548   8143
# 22  NaN  사망자수    192    220
# 23  NaN  부상자수  16674  12516
# 24   9월  사고건수   9793   8013
# 25  NaN  사망자수    211    219
# 26  NaN  부상자수  14741  12197
# 27  10월  사고건수  10785   9012
# 28  NaN  사망자수    236    263
# 29  NaN  부상자수  15991  13516
# 30  11월  사고건수  10435   8961
# 31  NaN  사망자수    223    256
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 4 columns):
# 월     12 non-null object
# 주야    36 non-null object
# 주     36 non-null int64
# 야     36 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 1.2+ KB

# %%
# 성별로 생존자수 확인

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.sex.value_counts() # 성별로 인원
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
titanic.groupby('sex')['survived'].mean().plot.bar()

# %%
titanic[(titanic.sex=='male')&(titanic.survived==1)].plot.bar()
