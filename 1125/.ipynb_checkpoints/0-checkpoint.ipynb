# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('hospitalInfo.csv', encoding='cp949') # load

# %%
data[~data['병원URL'].isnull()]
# Out:
#                                               암호화YKIHO코드         요양기관명  종별코드  \
# 0      JDQ4MTYyMiM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...  가톨릭대학교인천성모병원     1
# 1      JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...        강북삼성병원     1
# 2      JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...       건국대학교병원     1
# 3      JDQ4MTYyMiM4MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...       경북대학교병원     1
# 4      JDQ4MTYyMiM4MSMkMSMkNCMkODkkMzgxMzUxIzExIyQxIy...       경상대학교병원     1
# ...                                                  ...           ...   ...
# 72272  JDQ4MTYyMiM1MSMkMSMkMCMkMTMkNDgxMzUxIzQxIyQxIy...          휴한의원    93
# 72273  JDQ4MTYyMiM1MSMkMSMkMCMkMTMkNDgxNzAyIzExIyQyIy...          휴한의원    93
# 72282  JDU4MTI3MSM1MSMkMSMkMCMkMTMkMzgxNzAyIzMxIyQxIy...        흐를류한의원    93
# 72291  JDQ4MTYyMiM4MSMkMSMkNCMkMTMkMzgxNzAyIzUxIyQxIy...        흥시윤한의원    93
# 72313  JDQ4MTg4MSM1MSMkMSMkNCMkMTMkMzgxNzAyIzUxIyQxIy...     힘찬세상경희한의원    93
#
# ...

# %%
from collections import Counter

# %%
data[(data['시도코드명'] == '서울') & (data['종별코드명'] == '상급종합')]
# Out:
#                                            암호화YKIHO코드  \
# 1   JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 2   JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 5   JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 7   JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 15  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 16  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 22  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 28  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 32  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 36  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 37  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQyIy...
# 38  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 40  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
#
#                               요양기관명  종별코드 종별코드명    시도코드 시도코드명   시군구코드 시군구코드명  \
# 1                            강북삼성병원     1  상급종합  110000    서울  110016    종로구
# ...

# %%
data[(data['시도코드명'] == '서울') & (data['종별코드명'] == '상급종합')].value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-04095100ee65> in <module>
# ----> 1 data[(data['시도코드명'] == '서울') & (data['종별코드명'] == '상급종합')].value_counts()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
# 서울에 있는 상급종합병원을 구별로 평균갯수
