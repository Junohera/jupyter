# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.rcParams['font.family'] = 'Noto Sans CJK JP'

# %%
import pdvega

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# 담배피는 여부와 tip과의 관계

# %%
# 묶는 방법 두가지

# %%
tips.set_index(['smoker', 'sex', 'day']) # 1 like pivot
# Out:
#                     total_bill   tip    time  size
# smoker sex    day
# No     Female Sun        16.99  1.01  Dinner     2
#        Male   Sun        10.34  1.66  Dinner     3
#               Sun        21.01  3.50  Dinner     3
#               Sun        23.68  3.31  Dinner     2
#        Female Sun        24.59  3.61  Dinner     4
# ...                        ...   ...     ...   ...
#        Male   Sat        29.03  5.92  Dinner     3
# Yes    Female Sat        27.18  2.00  Dinner     2
#        Male   Sat        22.67  2.00  Dinner     2
# No     Male   Sat        17.82  1.75  Dinner     2
#        Female Thur       18.78  3.00  Dinner     2
#
# [244 rows x 4 columns]

# %%
tips.groupby('smoker').mean() # 2
# Out:
#         total_bill       tip      size
# smoker
# Yes      20.756344  3.008710  2.408602
# No       19.188278  2.991854  2.668874

# %%
tips.groupby('smoker').mean().index
# Out:
# CategoricalIndex(['Yes', 'No'], categories=['Yes', 'No'], ordered=False, name='smoker', dtype='category')

# %%
tips.groupby('smoker').mean().values
# Out:
# array([[20.75634409,  3.00870968,  2.40860215],
#        [19.18827815,  2.9918543 ,  2.66887417]])

# %%
tips.groupby('smoker').mean().columns
# Out:
# Index(['total_bill', 'tip', 'size'], dtype='object')

# %%
ax = tips.groupby('sex').mean()['tip'].plot.bar(figsize=(10,8))

# %%
# 남녀별 팁차이

# %%
tips['day']
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: category
# Categories (4, object): [Thur, Fri, Sat, Sun]

# %%
tips.day
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: category
# Categories (4, object): [Thur, Fri, Sat, Sun]

# %%
tips[['tip']].plot.line()

# %%
tips['tip'].plot.line()

# %%
tips.groupby('sex')[['tip']].mean().plot.bar()

# %%
plt.style.use('ggplot')
