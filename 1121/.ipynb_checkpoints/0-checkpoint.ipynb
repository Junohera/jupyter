# %%
import pandas as pd

# %%
import numpy as np

# %%
a = np.loadtxt
a = np.genfromtxt

# %%
b = pd.read_csv('acci.csv', encoding='cp949') # load

# %%
b.info() # dataFrame확인하기 
# padas에서는 object가 문자라고 생각하면됨!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10365 entries, 0 to 10364
# Data columns (total 16 columns):
# 사고지역관리번호       10365 non-null int64
# 사고년도           10365 non-null int64
# 사고유형구분         10365 non-null object
# 위치코드           10365 non-null int64
# 시도시군구명         10365 non-null object
# 사고지역위치명        10365 non-null object
# 발생건수           10365 non-null int64
# 사상자수           10365 non-null int64
# 사망자수           10365 non-null int64
# 중상자수           10365 non-null int64
# 경상자수           10365 non-null int64
# 부상자수           10365 non-null int64
# 위도             10365 non-null float64
# 경도             10365 non-null float64
# 사고다발지역폴리곤정보    10365 non-null object
# 데이터기준일자        10365 non-null object
# dtypes: float64(2), int64(9), object(5)
# memory usage: 1.3+ MB

# %%
b.describe() # summary
# Out:
#            사고지역관리번호          사고년도          위치코드          발생건수          사상자수  \
# count  1.036500e+04  10365.000000  1.036500e+04  10365.000000  10365.000000
# mean   2.015809e+06   2014.731693  6.909470e+07      4.750796      5.018138
# std    1.932015e+03      1.955133  1.018650e+08      2.038119      2.275687
# min    2.013060e+06   2012.000000  1.111000e+07      1.000000      0.000000
# 25%    2.014109e+06   2013.000000  2.623000e+07      3.000000      4.000000
# 50%    2.016146e+06   2015.000000  4.113500e+07      4.000000      4.000000
# 75%    2.017050e+06   2016.000000  4.713000e+07      5.000000      6.000000
# max    2.019066e+06   2018.000000  5.021040e+08     27.000000     31.000000
#
#                사망자수          중상자수          경상자수          부상자수            위도  \
# count  10365.000000  10365.000000  10365.000000  10365.000000  10365.000000
# mean       0.234250      2.389194      2.046792      0.348288     36.596723
# ...

# %%
b.describe(include='object') # summary - 문자열만 보기(object)
# Out:
#        사고유형구분      시도시군구명                  사고지역위치명  \
# count   10365       10365                    10365
# unique      5        2014                     8568
# top      보행노인  대구광역시 달서구1  대구광역시 서구 비산동(북비산네거리 부근)
# freq     3919          25                       10
#
#                                               사고다발지역폴리곤정보     데이터기준일자
# count                                               10365       10365
# unique                                              10322           1
# top     {type:Polygon,coordinates:[[[127.0166753,37.29...  2019-10-10
# freq                                                    2       10365

# %%
b.describe(include='all') # summary - 전체보기
# Out:
#             사고지역관리번호          사고년도 사고유형구분          위치코드      시도시군구명  \
# count   1.036500e+04  10365.000000  10365  1.036500e+04       10365
# unique           NaN           NaN      5           NaN        2014
# top              NaN           NaN   보행노인           NaN  대구광역시 달서구1
# freq             NaN           NaN   3919           NaN          25
# mean    2.015809e+06   2014.731693    NaN  6.909470e+07         NaN
# std     1.932015e+03      1.955133    NaN  1.018650e+08         NaN
# min     2.013060e+06   2012.000000    NaN  1.111000e+07         NaN
# 25%     2.014109e+06   2013.000000    NaN  2.623000e+07         NaN
# 50%     2.016146e+06   2015.000000    NaN  4.113500e+07         NaN
# 75%     2.017050e+06   2016.000000    NaN  4.713000e+07         NaN
# max     2.019066e+06   2018.000000    NaN  5.021040e+08         NaN
#
#                         사고지역위치명          발생건수          사상자수          사망자수  \
# count                     10365  10365.000000  10365.000000  10365.000000
# ...

# %%
b.describe().T #  열과 행 바꾸기 .T
# Out:
#             count          mean           std           min           25%  \
# 사고지역관리번호  10365.0  2.015809e+06  1.932015e+03  2.013060e+06  2.014109e+06
# 사고년도      10365.0  2.014732e+03  1.955133e+00  2.012000e+03  2.013000e+03
# 위치코드      10365.0  6.909470e+07  1.018650e+08  1.111000e+07  2.623000e+07
# 발생건수      10365.0  4.750796e+00  2.038119e+00  1.000000e+00  3.000000e+00
# 사상자수      10365.0  5.018138e+00  2.275687e+00  0.000000e+00  4.000000e+00
# 사망자수      10365.0  2.342499e-01  5.086327e-01  0.000000e+00  0.000000e+00
# 중상자수      10365.0  2.389194e+00  1.743488e+00  0.000000e+00  1.000000e+00
# 경상자수      10365.0  2.046792e+00  1.569080e+00  0.000000e+00  1.000000e+00
# 부상자수      10365.0  3.482875e-01  7.060609e-01  0.000000e+00  0.000000e+00
# 위도        10365.0  3.659672e+01  1.057973e+00  3.324724e+01  3.583092e+01
# 경도        10365.0  1.275407e+02  8.567837e-01  1.262574e+02  1.269133e+02
#
#                    50%           75%           max
# ...

# %%
dir(b)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
b
# Out:
#        사고지역관리번호  사고년도  사고유형구분       위치코드      시도시군구명  \
# 0       2013060  2012  스쿨존어린이   11110001  서울특별시 종로구1
# 1       2013060  2012  스쿨존어린이   11290001  서울특별시 성북구1
# 2       2013060  2012  스쿨존어린이   11290002  서울특별시 성북구2
# 3       2013060  2012  스쿨존어린이   11290003  서울특별시 성북구3
# 4       2013060  2012  스쿨존어린이   11320001  서울특별시 도봉구1
# ...         ...   ...     ...        ...         ...
# 10360   2019066  2018    무단횡단  280641002      경기 파주2
# 10361   2019066  2018    무단횡단  280641003      경기 파주3
# 10362   2019066  2018    무단횡단  280641004      경기 파주4
# 10363   2019066  2018    무단횡단  280941001      경기 구리1
# 10364   2019066  2018    무단횡단  281041001      경기 포천1
#
#                            사고지역위치명  발생건수  사상자수  사망자수  중상자수  경상자수  부상자수  \
# 0           서울특별시 종로구 혜화동(혜화초교 부근)     2     2     0     1     1     0
# 1           서울특별시 성북구 종암동(숭례초교 부근)     2     2     0     0     1     1
# 2        서울특별시 성북구 동소문동7가(정덕초교 부근)     2     2     0     2     0     0
# ...

# %%
b.values # numpy format
# Out:
# array([[2013060, 2012, '스쿨존어린이', ..., 126.9996071,
# ...

# %%
b['사고년도']
# Out:
# 0        2012
# 1        2012
# 2        2012
# 3        2012
# 4        2012
#          ...
# 10360    2018
# 10361    2018
# 10362    2018
# 10363    2018
# 10364    2018
# Name: 사고년도, Length: 10365, dtype: int64

# %%
type(b['사고년도'])
# Out:
# pandas.core.series.Series

# %%
b.위치코드 #
# Out:
# 0         11110001
# 1         11290001
# 2         11290002
# 3         11290003
# 4         11320001
#            ...
# 10360    280641002
# 10361    280641003
# 10362    280641004
# 10363    280941001
# 10364    281041001
# Name: 위치코드, Length: 10365, dtype: int64

# %%
b.iloc[0]
# Out:
# 사고지역관리번호                                                 2013060
# 사고년도                                                        2012
# 사고유형구분                                                    스쿨존어린이
# 위치코드                                                    11110001
# 시도시군구명                                                서울특별시 종로구1
# 사고지역위치명                                   서울특별시 종로구 혜화동(혜화초교 부근)
# 발생건수                                                           2
# 사상자수                                                           2
# 사망자수                                                           0
# 중상자수                                                           1
# 경상자수                                                           1
# 부상자수                                                           0
# 위도                                                       37.5884
# 경도                                                           127
# ...

# %%
.iloc[1:100]
# Out:
#     사고지역관리번호  사고년도  사고유형구분      위치코드      시도시군구명  \
# 1    2013060  2012  스쿨존어린이  11290001  서울특별시 성북구1
# 2    2013060  2012  스쿨존어린이  11290002  서울특별시 성북구2
# 3    2013060  2012  스쿨존어린이  11290003  서울특별시 성북구3
# 4    2013060  2012  스쿨존어린이  11320001  서울특별시 도봉구1
# 5    2013060  2012  스쿨존어린이  11350001  서울특별시 노원구1
# ..       ...   ...     ...       ...         ...
# 95   2013097  2012   보행어린이  27290008  대구광역시 달서구8
# 96   2013097  2012   보행어린이  27710001  대구광역시 달성군1
# 97   2013097  2012   보행어린이  28170001   인천광역시 남구1
# 98   2013097  2012   보행어린이  28185001  인천광역시 연수구1
# 99   2013097  2012   보행어린이  28200001  인천광역시 남동구1
#
#                          사고지역위치명  발생건수  사상자수  사망자수  중상자수  경상자수  부상자수  \
# 1         서울특별시 성북구 종암동(숭례초교 부근)     2     2     0     0     1     1
# 2      서울특별시 성북구 동소문동7가(정덕초교 부근)     2     2     0     2     0     0
# 3         서울특별시 성북구 석관동(석관초교 부근)     3     3     0     2     1     0
# 4         서울특별시 도봉구 쌍문동(쌍문초교 부근)     2     2     0     0     2     0
# ...

# %%
b.iloc[1:100, 1]
# Out:
# 1     2012
# 2     2012
# 3     2012
# 4     2012
# 5     2012
#       ...
# 95    2012
# 96    2012
# 97    2012
# 98    2012
# 99    2012
# Name: 사고년도, Length: 99, dtype: int64

# %%
b.loc(0)

# %%
b.log[o:3]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-fd140241658e> in <module>
# ----> 1 b.log[o:3]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'log'

# %%
b.log[0:3]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-a13cb1bf674d> in <module>
# ----> 1 b.log[0:3]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'log'

# %%
b.loc[0:,3, '위치코드':'시도시군구면']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-bb08ed4ee20a> in <module>
# ----> 1 b.loc[0:,3, '위치코드':'시도시군구면']
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     808
#     809         # no multi-index, so validate all of the indexers
# --> 810         self._has_valid_tuple(tup)
#     811
#     812         # ugly hack for GH #836
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
# ...

# %%
b.iat(0,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-836e4703f077> in <module>
# ----> 1 b.iat(0,2)
#
# TypeError: __call__() takes from 1 to 2 positional arguments but 3 were given

# %%
b[b['사고년도']== 2012]
# Out:
#       사고지역관리번호  사고년도  사고유형구분       위치코드      시도시군구명  \
# 0      2013060  2012  스쿨존어린이   11110001  서울특별시 종로구1
# 1      2013060  2012  스쿨존어린이   11290001  서울특별시 성북구1
# 2      2013060  2012  스쿨존어린이   11290002  서울특별시 성북구2
# 3      2013060  2012  스쿨존어린이   11290003  서울특별시 성북구3
# 4      2013060  2012  스쿨존어린이   11320001  서울특별시 도봉구1
# ...        ...   ...     ...        ...         ...
# 1753   2013114  2012    무단횡단  502103002     제주 서귀포2
# 1754   2013114  2012    무단횡단  502104001    제주 제주서부1
# 1755   2013114  2012    무단횡단  502104002    제주 제주서부2
# 1756   2013114  2012    무단횡단  502104003    제주 제주서부3
# 1757   2013114  2012    무단횡단  502104004    제주 제주서부4
#
#                           사고지역위치명  발생건수  사상자수  사망자수  중상자수  경상자수  부상자수  \
# 0          서울특별시 종로구 혜화동(혜화초교 부근)     2     2     0     1     1     0
# 1          서울특별시 성북구 종암동(숭례초교 부근)     2     2     0     0     1     1
# 2       서울특별시 성북구 동소문동7가(정덕초교 부근)     2     2     0     2     0     0
# ...

# %%
# 20130602 사고지역관리번호가 20130602의 모든데이터

# %%
b[b['사고지역관리번호'] == 2013060].shape
# Out:
# (35, 16)

# %%
b[b['사고지역관리번호'] == 2013060].size
# Out:
# 560

# %%
# 중상자수 >= 2

# %%
b[b['중상자수'] >= 2].shape
# Out:
# (7004, 16)

# %%
b[b['중상자수'] >= 2].iloc[0:3] # index상관없이
# Out:
#     사고지역관리번호  사고년도  사고유형구분      위치코드       시도시군구명                    사고지역위치명  \
# 2    2013060  2012  스쿨존어린이  11290002   서울특별시 성북구2  서울특별시 성북구 동소문동7가(정덕초교 부근)
# 3    2013060  2012  스쿨존어린이  11290003   서울특별시 성북구3     서울특별시 성북구 석관동(석관초교 부근)
# 11   2013060  2012  스쿨존어린이  26350001  부산광역시 해운대구1    부산광역시 해운대구 반여동(장산초교 부근)
#
#     발생건수  사상자수  사망자수  중상자수  경상자수  부상자수         위도          경도  \
# 2      2     2     0     2     0     0  37.597571  127.014564
# 3      3     3     0     2     1     0  37.610429  127.059596
# 11     2     2     0     2     0     0  35.199556  129.119107
#
#                                           사고다발지역폴리곤정보     데이터기준일자
# 2   {type:Polygon,coordinates:[[[127.0169658,37.59...  2019-10-10
# 3   {type:Polygon,coordinates:[[[127.0619982,37.61...  2019-10-10
# 11  {type:Polygon,coordinates:[[[129.121437,35.201...  2019-10-10

# %%
b[b['중상자수'] >= 2].loc[2:3] # index로
# Out:
#    사고지역관리번호  사고년도  사고유형구분      위치코드      시도시군구명                    사고지역위치명  \
# 2   2013060  2012  스쿨존어린이  11290002  서울특별시 성북구2  서울특별시 성북구 동소문동7가(정덕초교 부근)
# 3   2013060  2012  스쿨존어린이  11290003  서울특별시 성북구3     서울특별시 성북구 석관동(석관초교 부근)
#
#    발생건수  사상자수  사망자수  중상자수  경상자수  부상자수         위도          경도  \
# 2     2     2     0     2     0     0  37.597571  127.014564
# 3     3     3     0     2     1     0  37.610429  127.059596
#
#                                          사고다발지역폴리곤정보     데이터기준일자
# 2  {type:Polygon,coordinates:[[[127.0169658,37.59...  2019-10-10
# 3  {type:Polygon,coordinates:[[[127.0619982,37.61...  2019-10-10

# %%
# 중상자수 == 2 && 경상자수 > 1

# %%
b[(b['중상자수'] >= 2) & (b['경상자수'] > 2)]
# Out:
#        사고지역관리번호  사고년도 사고유형구분       위치코드         시도시군구명  \
# 42      2013097  2012  보행어린이   11290001     서울특별시 성북구1
# 66      2013097  2012  보행어린이   11710005     서울특별시 송파구5
# 136     2013097  2012  보행어린이   41271003   경기도 안산시 상록구3
# 165     2013097  2012  보행어린이   43111002  충청북도 청주시 상당구2
# 179     2013097  2012  보행어린이   45113001  전라북도 전주시 덕진구1
# ...         ...   ...    ...        ...            ...
# 10346   2019066  2018   무단횡단  220627001       대구 대구달서1
# 10357   2019066  2018   무단횡단  280341001         경기 고양1
# 10360   2019066  2018   무단횡단  280641002         경기 파주2
# 10361   2019066  2018   무단횡단  280641003         경기 파주3
# 10363   2019066  2018   무단횡단  280941001         경기 구리1
#
#                             사고지역위치명  발생건수  사상자수  사망자수  중상자수  경상자수  부상자수  \
# 42     서울특별시 성북구 종암동(종암동 근린생활시설 부근)     4     5     0     2     3     0
# 66        서울특별시 송파구 가락동(가락대림사거리 부근)     4     6     0     2     4     0
# 136      경기도 안산시 상록구 수암동(선경드림타운 부근)     3     7     1     2     4     0
# ...
