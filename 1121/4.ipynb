# %%
import pandas as pd
import numpy as np

# %%
b = pd.read_csv('acci.csv', encoding='cp949') # load

# %%
b['시도시군구명'] # series
# Out:
# 0        서울특별시 종로구1
# 1        서울특별시 성북구1
# 2        서울특별시 성북구2
# 3        서울특별시 성북구3
# 4        서울특별시 도봉구1
#             ...
# 10360        경기 파주2
# 10361        경기 파주3
# 10362        경기 파주4
# 10363        경기 구리1
# 10364        경기 포천1
# Name: 시도시군구명, Length: 10365, dtype: object

# %%
b[['시도시군구명']] # dataParam
# Out:
#            시도시군구명
# 0      서울특별시 종로구1
# 1      서울특별시 성북구1
# 2      서울특별시 성북구2
# 3      서울특별시 성북구3
# 4      서울특별시 도봉구1
# ...           ...
# 10360      경기 파주2
# 10361      경기 파주3
# 10362      경기 파주4
# 10363      경기 구리1
# 10364      경기 포천1
#
# [10365 rows x 1 columns]

# %%
b['시도시군구명'].str # .str하면 python의 string 기본 함수 그대로 사용할 수 있음.

# %%
x = b['시도시군구명'].str

# %%
x.split(expand=True)
# Out:
#            0     1     2
# 0      서울특별시  종로구1  None
# 1      서울특별시  성북구1  None
# 2      서울특별시  성북구2  None
# 3      서울특별시  성북구3  None
# 4      서울특별시  도봉구1  None
# ...      ...   ...   ...
# 10360     경기   파주2  None
# 10361     경기   파주3  None
# 10362     경기   파주4  None
# 10363     경기   구리1  None
# 10364     경기   포천1  None
#
# [10365 rows x 3 columns]

# %%
t = x.split(expand=True).rename({0:'시',1:'군',2:'구'}, axis = 1)

# %%
pd.concat([b, t], axis = 1)
# Out:
#        사고지역관리번호  사고년도  사고유형구분       위치코드      시도시군구명  \
# 0       2013060  2012  스쿨존어린이   11110001  서울특별시 종로구1
# 1       2013060  2012  스쿨존어린이   11290001  서울특별시 성북구1
# 2       2013060  2012  스쿨존어린이   11290002  서울특별시 성북구2
# 3       2013060  2012  스쿨존어린이   11290003  서울특별시 성북구3
# 4       2013060  2012  스쿨존어린이   11320001  서울특별시 도봉구1
# ...         ...   ...     ...        ...         ...
# 10360   2019066  2018    무단횡단  280641002      경기 파주2
# 10361   2019066  2018    무단횡단  280641003      경기 파주3
# 10362   2019066  2018    무단횡단  280641004      경기 파주4
# 10363   2019066  2018    무단횡단  280941001      경기 구리1
# 10364   2019066  2018    무단횡단  281041001      경기 포천1
#
#                            사고지역위치명  발생건수  사상자수  사망자수  중상자수  경상자수  부상자수  \
# 0           서울특별시 종로구 혜화동(혜화초교 부근)     2     2     0     1     1     0
# 1           서울특별시 성북구 종암동(숭례초교 부근)     2     2     0     0     1     1
# 2        서울특별시 성북구 동소문동7가(정덕초교 부근)     2     2     0     2     0     0
# ...

# %%
# 서울특별시의 특별을 제거하기

# %%
x = b['시도시군구명'].str.replace('특별','')

# %%
x
# Out:
# 0        서울시 종로구1
# 1        서울시 성북구1
# 2        서울시 성북구2
# 3        서울시 성북구3
# 4        서울시 도봉구1
#            ...
# 10360      경기 파주2
# 10361      경기 파주3
# 10362      경기 파주4
# 10363      경기 구리1
# 10364      경기 포천1
# Name: 시도시군구명, Length: 10365, dtype: object

# %%
x = b['시도시군구명'].str

# %%
x.contains
# Out:
# <bound method StringMethods.contains of <pandas.core.strings.StringMethods object at 0x7f408caed090>>
